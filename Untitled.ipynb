# %%
import numpy as np
import CoolProp.CoolProp as CP
import CoolProp.Plots as CPP
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('Tables/Toluene_PT.txt', sep='\t')

# %%
fig, ax =plt.subplots()
df[abs(df["P"] -18)<1e-5].plot(x='T', y='c_PR', ax=ax)
df[abs(df["P"] -18)<1e-5].plot(x='T', y='c_IG', ax=ax)
df[abs(df["P"] -18)<1e-5].plot(x='T', y='c_CP', ax=ax)
ax.set_xlim([540, 600])
# ax.set_ylim([0,70])
# Out:
# (540, 600)

# %%
fig, ax =plt.subplots()
df[abs(df["P"] -18)<1e-5].plot(x='T', y='rho', ax=ax)
df[abs(df["P"] -18)<1e-5].plot(x='T', y='rho_CP', ax=ax)
ax.set_xlim([540, 600])
ax.set_ylim([0,70])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-176-48974612c247> in <module>()
#       1 fig, ax =plt.subplots()
# ----> 2 df[abs(df["P"] -18)<1e-5].plot(x='T', y='rho', ax=ax)
#       3 df[abs(df["P"] -18)<1e-5].plot(x='T', y='rho_CP', ax=ax)
#       4 ax.set_xlim([540, 600])
#       5 ax.set_ylim([0,70])
#
# /usr/local/lib/python2.7/dist-packages/pandas/plotting/_core.pyc in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2625                           fontsize=fontsize, colormap=colormap, table=table,
#    2626                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2627                           sort_columns=sort_columns, **kwds)
# ...

# %%
fig, ax =plt.subplots()
df[abs(df["P"] -10)<1e-5].plot(x='T', y='mu', ax=ax)
df[abs(df["P"] -10)<1e-5].plot(x='T', y='mu_CP', ax=ax)
ax.set_xlim([540, 600])
ax.set_ylim([10e-6,17e-6])
# Out:
# (1e-05, 1.7e-05)

# %%
fig, ax =plt.subplots()
df[abs(df["P"] -12.)<1e-5].plot(x='T', y='k', ax=ax)
df[abs(df["P"] -12.)<1e-5].plot(x='T', y='k_CP', ax=ax)
ax.set_xlim([540, 600])
ax.set_ylim([0.03,0.05])
# Out:
# (0.03, 0.05)

# %%
fig, ax =plt.subplots()
df[abs(df["P"] -12.)<1e-5].plot(x='T', y='cp', ax=ax)
df[abs(df["P"] -12.)<1e-5].plot(x='T', y='cp_CP', ax=ax)
ax.set_xlim([540, 600])
# ax.set_ylim([0.03,0.05])
# Out:
# (540, 600)

# %%
fig, ax =plt.subplots()
df[abs(df["P"] -12.)<1e-5].plot(x='T', y='c', ax=ax)
df[abs(df["P"] -12.)<1e-5].plot(x='T', y='c_CP', ax=ax)
ax.set_xlim([540, 600])
# ax.set_ylim([0.03,0.05])
# Out:
# (540, 600)
